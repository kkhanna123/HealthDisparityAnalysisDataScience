# %% [markdown]
# # Cleaning and preparing the raw education census data

# %% [markdown]
# Since this dataset is so large, we will import only the first 100 rows to first examine which columns we will actually need.

# %%
import pandas as pd
first100rows = pd.read_csv("../CensusData/EducationCensusDataFull.csv", nrows=100)

# %%
first100rows.head()
# Out:
#                      id                       Geographic Area Name  \
# 0  1400000US01001020100  Census Tract 201, Autauga County, Alabama
# 1  1400000US01001020200  Census Tract 202, Autauga County, Alabama
# 2  1400000US01001020300  Census Tract 203, Autauga County, Alabama
# 3  1400000US01001020400  Census Tract 204, Autauga County, Alabama
# 4  1400000US01001020500  Census Tract 205, Autauga County, Alabama
#
#    Estimate!!Total!!Population 18 to 24 years  \
# 0                                         172
# 1                                         198
# 2                                         250
# 3                                         340
# 4                                         611
#
#    Margin of Error!!Total MOE!!Population 18 to 24 years  \
# 0                                                 83
# 1                                                 80
# 2                                                 99
# 3                                                111
# 4                                                233
#
#    Estimate!!Total!!Population 18 to 24 years!!Less than high school graduate  \
# 0                                                  5
# 1                                                 41
# 2                                                 22
# 3                                                 16
# 4                                                 33
#
#    Margin of Error!!Total MOE!!Population 18 to 24 years!!Less than high school graduate  \
# 0                                                  7
# 1                                                 29
# 2                                                 23
# 3                                                 20
# 4                                                 62
#
#    Estimate!!Total!!Population 18 to 24 years!!High school graduate (includes equivalency)  \
# 0                                                 64
# 1                                                 86
# 2                                                128
# 3                                                188
# 4                                                213
#
#    Margin of Error!!Total MOE!!Population 18 to 24 years!!High school graduate (includes equivalency)  \
# 0                                                 46
# 1                                                 68
# 2                                                 62
# 3                                                 94
# 4                                                130
#
#    Estimate!!Total!!Population 18 to 24 years!!Some college or associate's degree  \
# 0                                                 83
# 1                                                 54
# 2                                                 49
# 3                                                128
# 4                                                121
#
#    Margin of Error!!Total MOE!!Population 18 to 24 years!!Some college or associate's degree  \
# 0                                                 66
# 1                                                 38
# 2                                                 41
# 3                                                 82
# 4                                                132
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Estimate!!Percent Female!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Less than high school graduate  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Margin of Error!!Percent Female MOE!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Less than high school graduate  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!Percent Female!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!High school graduate (includes equivalency)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Margin of Error!!Percent Female MOE!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!High school graduate (includes equivalency)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!Percent Female!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Some college or associate's degree  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Margin of Error!!Percent Female MOE!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Some college or associate's degree  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!Percent Female!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Bachelor's degree  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Margin of Error!!Percent Female MOE!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Bachelor's degree  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!Percent Female!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Graduate or professional degree  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Margin of Error!!Percent Female MOE!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Graduate or professional degree
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 770 columns]

# %% [markdown]
# It looks like some columns are filled with just a singular value (`(X)` for example), which need to be thrown out.

# %%
# Find all the columns with only 1 value
columns = first100rows.columns
bad_columns = []
for column in columns:
    if len(first100rows[column].value_counts()) <= 1:
        bad_columns.append(column)
len(bad_columns)
# Out:
# 165

# %%
first100rows = first100rows.drop(columns=bad_columns)

# %% [markdown]
# Now that the data is a little more cleaned up, we can decide which columns contain data that we actually want.

# %%
first100rows.head(0)
# Out:
# Empty DataFrame
# Columns: [id, Geographic Area Name, Estimate!!Total!!Population 18 to 24 years, Margin of Error!!Total MOE!!Population 18 to 24 years, Estimate!!Total!!Population 18 to 24 years!!Less than high school graduate, Margin of Error!!Total MOE!!Population 18 to 24 years!!Less than high school graduate, Estimate!!Total!!Population 18 to 24 years!!High school graduate (includes equivalency), Margin of Error!!Total MOE!!Population 18 to 24 years!!High school graduate (includes equivalency), Estimate!!Total!!Population 18 to 24 years!!Some college or associate's degree, Margin of Error!!Total MOE!!Population 18 to 24 years!!Some college or associate's degree, Estimate!!Total!!Population 18 to 24 years!!Bachelor's degree or higher, Margin of Error!!Total MOE!!Population 18 to 24 years!!Bachelor's degree or higher, Estimate!!Total!!Population 25 years and over, Margin of Error!!Total MOE!!Population 25 years and over, Estimate!!Total!!Population 25 years and over!!Less than 9th grade, Margin of Error!!Total MOE!!Population 25 years and over!!Less than 9th grade, Estimate!!Total!!Population 25 years and over!!9th to 12th grade, no diploma, Margin of Error!!Total MOE!!Population 25 years and over!!9th to 12th grade, no diploma, Estimate!!Total!!Population 25 years and over!!High school graduate (includes equivalency), Margin of Error!!Total MOE!!Population 25 years and over!!High school graduate (includes equivalency), Estimate!!Total!!Population 25 years and over!!Some college, no degree, Margin of Error!!Total MOE!!Population 25 years and over!!Some college, no degree, Estimate!!Total!!Population 25 years and over!!Associate's degree, Margin of Error!!Total MOE!!Population 25 years and over!!Associate's degree, Estimate!!Total!!Population 25 years and over!!Bachelor's degree, Margin of Error!!Total MOE!!Population 25 years and over!!Bachelor's degree, Estimate!!Total!!Population 25 years and over!!Graduate or professional degree, Margin of Error!!Total MOE!!Population 25 years and over!!Graduate or professional degree, Estimate!!Total!!Population 25 years and over!!Population 25 to 34 years, Margin of Error!!Total MOE!!Population 25 years and over!!Population 25 to 34 years, Estimate!!Total!!Population 25 years and over!!Population 25 to 34 years!!High school graduate or higher, Margin of Error!!Total MOE!!Population 25 years and over!!Population 25 to 34 years!!High school graduate or higher, Estimate!!Total!!Population 25 years and over!!Population 25 to 34 years!!Bachelor's degree or higher, Margin of Error!!Total MOE!!Population 25 years and over!!Population 25 to 34 years!!Bachelor's degree or higher, Estimate!!Total!!Population 25 years and over!!Population 35 to 44 years, Margin of Error!!Total MOE!!Population 25 years and over!!Population 35 to 44 years, Estimate!!Total!!Population 25 years and over!!Population 35 to 44 years!!High school graduate or higher, Margin of Error!!Total MOE!!Population 25 years and over!!Population 35 to 44 years!!High school graduate or higher, Estimate!!Total!!Population 25 years and over!!Population 35 to 44 years!!Bachelor's degree or higher, Margin of Error!!Total MOE!!Population 25 years and over!!Population 35 to 44 years!!Bachelor's degree or higher, Estimate!!Total!!Population 25 years and over!!Population 45 to 64 years, Margin of Error!!Total MOE!!Population 25 years and over!!Population 45 to 64 years, Estimate!!Total!!Population 25 years and over!!Population 45 to 64 years!!High school graduate or higher, Margin of Error!!Total MOE!!Population 25 years and over!!Population 45 to 64 years!!High school graduate or higher, Estimate!!Total!!Population 25 years and over!!Population 45 to 64 years!!Bachelor's degree or higher, Margin of Error!!Total MOE!!Population 25 years and over!!Population 45 to 64 years!!Bachelor's degree or higher, Estimate!!Total!!Population 25 years and over!!Population 65 years and over, Margin of Error!!Total MOE!!Population 25 years and over!!Population 65 years and o ...
# Index: []
#
# [0 rows x 605 columns]

# %% [markdown]
# It looks like the column names are extremely long with some holding data that we already have or data that we simply don't need. First, we can drop all the margin of error columns.

# %%
first100rows = first100rows.drop([column for column in first100rows.columns if "Margin of Error" in column], axis=1)

# %% [markdown]
# Since we already have data on race and gender per tract, we can ignore those columns to save space.

# %%
first100rows = first100rows.drop([column for column in first100rows.columns if ("RACE" in column) or ("Male" in column) or ("Female" in column)], axis=1)

# %%
first100rows.columns
# Out:
# Index(['id', 'Geographic Area Name',
#        'Estimate!!Total!!Population 18 to 24 years',
#        'Estimate!!Total!!Population 18 to 24 years!!Less than high school graduate',
#        'Estimate!!Total!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#        'Estimate!!Total!!Population 18 to 24 years!!Some college or associate's degree',
#        'Estimate!!Total!!Population 18 to 24 years!!Bachelor's degree or higher',
#        'Estimate!!Total!!Population 25 years and over',
#        'Estimate!!Total!!Population 25 years and over!!Less than 9th grade',
#        'Estimate!!Total!!Population 25 years and over!!9th to 12th grade, no diploma',
#        'Estimate!!Total!!Population 25 years and over!!High school graduate (includes equivalency)',
#        'Estimate!!Total!!Population 25 years and over!!Some college, no degree',
#        'Estimate!!Total!!Population 25 years and over!!Associate's degree',
#        'Estimate!!Total!!Population 25 years and over!!Bachelor's degree',
#        'Estimate!!Total!!Population 25 years and over!!Graduate or professional degree',
#        'Estimate!!Total!!Population 25 years and over!!Population 25 to 34 years',
#        'Estimate!!Total!!Population 25 years and over!!Population 25 to 34 years!!High school graduate or higher',
#        'Estimate!!Total!!Population 25 years and over!!Population 25 to 34 years!!Bachelor's degree or higher',
#        'Estimate!!Total!!Population 25 years and over!!Population 35 to 44 years',
#        'Estimate!!Total!!Population 25 years and over!!Population 35 to 44 years!!High school graduate or higher',
#        'Estimate!!Total!!Population 25 years and over!!Population 35 to 44 years!!Bachelor's degree or higher',
#        'Estimate!!Total!!Population 25 years and over!!Population 45 to 64 years',
#        'Estimate!!Total!!Population 25 years and over!!Population 45 to 64 years!!High school graduate or higher',
#        'Estimate!!Total!!Population 25 years and over!!Population 45 to 64 years!!Bachelor's degree or higher',
#        'Estimate!!Total!!Population 25 years and over!!Population 65 years and over',
#        'Estimate!!Total!!Population 25 years and over!!Population 65 years and over!!High school graduate or higher',
#        'Estimate!!Total!!Population 25 years and over!!Population 65 years and over!!Bachelor's degree or higher',
#        'Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings',
#        'Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Less than high school graduate',
#        'Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!High school graduate (includes equivalency)',
#        'Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Some college or associate's degree',
#        'Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Bachelor's degree',
#        'Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Population 25 years and over with earnings!!Graduate or professional degree',
#        'Estimate!!Percent!!Population 18 to 24 years!!Less than high school graduate',
#        'Estimate!!Percent!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!Population 18 to 24 years!!Some college or associate's degree',
#        'Estimate!!Percent!!Population 18 to 24 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Less than 9th grade',
#        'Estimate!!Percent!!Population 25 years and over!!9th to 12th grade, no diploma',
#        'Estimate!!Percent!!Population 25 years and over!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!Population 25 years and over!!Some college, no degree',
#        'Estimate!!Percent!!Population 25 years and over!!Associate's degree',
#        'Estimate!!Percent!!Population 25 years and over!!Bachelor's degree',
#        'Estimate!!Percent!!Population 25 years and over!!Graduate or professional degree',
#        'Estimate!!Percent!!Population 25 years and over!!Percent high school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Percent bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 25 to 34 years!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 25 to 34 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 35 to 44 years!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 35 to 44 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 45 to 64 years!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 45 to 64 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 65 years and over!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 65 years and over!!Bachelor's degree or higher',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Less than high school graduate',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Some college or associate's degree',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Bachelor's degree or higher'],
#       dtype='object')

# %% [markdown]
# We can also notice that every data point is represented twice through both total population and the percentage of the population. This means we can keep either one without losing much information. We will be keeping the percentage because it's a more comparable metric across different populations.

# %%
first100rows = first100rows.drop([column for column in first100rows.columns if "!!Total!!" in column], axis=1)

# %%
first100rows.columns
# Out:
# Index(['id', 'Geographic Area Name',
#        'Estimate!!Percent!!Population 18 to 24 years!!Less than high school graduate',
#        'Estimate!!Percent!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!Population 18 to 24 years!!Some college or associate's degree',
#        'Estimate!!Percent!!Population 18 to 24 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Less than 9th grade',
#        'Estimate!!Percent!!Population 25 years and over!!9th to 12th grade, no diploma',
#        'Estimate!!Percent!!Population 25 years and over!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!Population 25 years and over!!Some college, no degree',
#        'Estimate!!Percent!!Population 25 years and over!!Associate's degree',
#        'Estimate!!Percent!!Population 25 years and over!!Bachelor's degree',
#        'Estimate!!Percent!!Population 25 years and over!!Graduate or professional degree',
#        'Estimate!!Percent!!Population 25 years and over!!Percent high school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Percent bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 25 to 34 years!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 25 to 34 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 35 to 44 years!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 35 to 44 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 45 to 64 years!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 45 to 64 years!!Bachelor's degree or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 65 years and over!!High school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Population 65 years and over!!Bachelor's degree or higher',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Less than high school graduate',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Some college or associate's degree',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Bachelor's degree or higher'],
#       dtype='object')

# %% [markdown]
# Since we're not examining inequality in age across in this project, we can drop the age specific columns

# %%
first100rows = first100rows.drop([column for column in first100rows.columns if "to" in column or "65 years" in column], axis=1)

# %%
first100rows.columns
# Out:
# Index(['id', 'Geographic Area Name',
#        'Estimate!!Percent!!Population 25 years and over!!Less than 9th grade',
#        'Estimate!!Percent!!Population 25 years and over!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!Population 25 years and over!!Some college, no degree',
#        'Estimate!!Percent!!Population 25 years and over!!Associate's degree',
#        'Estimate!!Percent!!Population 25 years and over!!Bachelor's degree',
#        'Estimate!!Percent!!Population 25 years and over!!Graduate or professional degree',
#        'Estimate!!Percent!!Population 25 years and over!!Percent high school graduate or higher',
#        'Estimate!!Percent!!Population 25 years and over!!Percent bachelor's degree or higher',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Less than high school graduate',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!High school graduate (includes equivalency)',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Some college or associate's degree',
#        'Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Bachelor's degree or higher'],
#       dtype='object')

# %%
df = pd.read_csv("../CensusData/EducationCensusDataFull.csv", usecols=first100rows.columns)
df.head()
# Out:
#                      id                       Geographic Area Name  \
# 0  1400000US01001020100  Census Tract 201, Autauga County, Alabama
# 1  1400000US01001020200  Census Tract 202, Autauga County, Alabama
# 2  1400000US01001020300  Census Tract 203, Autauga County, Alabama
# 3  1400000US01001020400  Census Tract 204, Autauga County, Alabama
# 4  1400000US01001020500  Census Tract 205, Autauga County, Alabama
#
#   Estimate!!Percent!!Population 25 years and over!!Less than 9th grade  \
# 0                                                3.0
# 1                                                2.8
# 2                                                4.6
# 3                                                4.0
# 4                                                2.1
#
#   Estimate!!Percent!!Population 25 years and over!!High school graduate (includes equivalency)  \
# 0                                               29.4
# 1                                               39.9
# 2                                               36.0
# 3                                               36.5
# 4                                               23.4
#
#   Estimate!!Percent!!Population 25 years and over!!Some college, no degree  \
# 0                                               17.3
# 1                                               18.6
# 2                                               26.0
# 3                                               18.2
# 4                                               21.6
#
#   Estimate!!Percent!!Population 25 years and over!!Associate's degree  \
# 0                                                6.1
# 1                                                7.2
# 2                                                6.3
# 3                                                8.4
# 4                                                8.6
#
#   Estimate!!Percent!!Population 25 years and over!!Bachelor's degree  \
# 0                                               20.7
# 1                                               11.3
# 2                                               10.0
# 3                                               18.2
# 4                                               21.2
#
#   Estimate!!Percent!!Population 25 years and over!!Graduate or professional degree  \
# 0                                               17.1
# 1                                                4.9
# 2                                                8.1
# 3                                                8.5
# 4                                               19.4
#
#   Estimate!!Percent!!Population 25 years and over!!Percent high school graduate or higher  \
# 0                                               90.6
# 1                                               82.0
# 2                                               86.3
# 3                                               90.0
# 4                                               94.1
#
#   Estimate!!Percent!!Population 25 years and over!!Percent bachelor's degree or higher  \
# 0                                               37.8
# 1                                               16.2
# 2                                               18.1
# 3                                               26.7
# 4                                               40.5
#
#   Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Less than high school graduate  \
# 0                                                2.5
# 1                                               59.8
# 2                                               17.6
# 3                                                0.0
# 4                                               61.6
#
#   Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!High school graduate (includes equivalency)  \
# 0                                               11.1
# 1                                               20.5
# 2                                               16.7
# 3                                                0.8
# 4                                               10.1
#
#   Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Some college or associate's degree  \
# 0                                               15.3
# 1                                                2.7
# 2                                                9.8
# 3                                                2.3
# 4                                                2.2
#
#   Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Bachelor's degree or higher
# 0                                                2.3
# 1                                                6.3
# 2                                                7.6
# 3                                                2.5
# 4                                                4.9

# %% [markdown]
# It looks like there are some NaN values that are not being properly interpreted as NaN, such as `-`.

# %%
# Get all the columns that are "object" type and might actually be numeric
object_cols = [column for column in df.columns if str(df[column].dtype) == "object"]
len(object_cols)
# Out:
# 14

# %%
# Find the columns that have a numeric value
def is_numeric(sus_string):
    try:
        float(sus_string)
    except:
        return False
    return True

def has_numeric(column):
    global df
    for val in df[column]:
        if is_numeric(val):
            return True
    return False

suspicious_columns = [column for column in object_cols if has_numeric(column)]
len(suspicious_columns)
# Out:
# 12

# %%
# Preview which columns were marked as suspicious
first100rows[suspicious_columns].head(20)
# Out:
#    Estimate!!Percent!!Population 25 years and over!!Less than 9th grade  \
# 0                                                 3.0
# 1                                                 2.8
# 2                                                 4.6
# 3                                                 4.0
# 4                                                 2.1
# 5                                                 4.0
# 6                                                 1.7
# 7                                                 2.1
# 8                                                 2.4
# 9                                                 1.0
# 10                                                8.7
# 11                                                4.2
# 12                                                8.5
# 13                                                2.4
# 14                                                5.2
# 15                                                2.9
# 16                                                1.8
# 17                                                6.5
# 18                                                2.1
# 19                                                0.8
#
#    Estimate!!Percent!!Population 25 years and over!!High school graduate (includes equivalency)  \
# 0                                                29.4
# 1                                                39.9
# 2                                                36.0
# 3                                                36.5
# 4                                                23.4
# 5                                                33.6
# 6                                                40.9
# 7                                                22.0
# 8                                                34.6
# 9                                                39.8
# 10                                               37.9
# 11                                               42.9
# 12                                               34.6
# 13                                               44.9
# 14                                               38.2
# 15                                               37.3
# 16                                               32.4
# 17                                               35.4
# 18                                               14.1
# 19                                               14.6
#
#    Estimate!!Percent!!Population 25 years and over!!Some college, no degree  \
# 0                                                17.3
# 1                                                18.6
# 2                                                26.0
# 3                                                18.2
# 4                                                21.6
# 5                                                20.8
# 6                                                20.2
# 7                                                20.7
# 8                                                22.9
# 9                                                28.1
# 10                                               14.8
# 11                                               16.1
# 12                                               16.6
# 13                                               25.9
# 14                                               19.3
# 15                                               20.3
# 16                                               25.4
# 17                                               17.6
# 18                                               18.8
# 19                                               19.6
#
#    Estimate!!Percent!!Population 25 years and over!!Associate's degree  \
# 0                                                 6.1
# 1                                                 7.2
# 2                                                 6.3
# 3                                                 8.4
# 4                                                 8.6
# 5                                                 6.8
# 6                                                 7.6
# 7                                                13.8
# 8                                                 7.5
# 9                                                 5.1
# 10                                                5.6
# 11                                                8.4
# 12                                                9.8
# 13                                                9.5
# 14                                               12.5
# 15                                                9.8
# 16                                                9.6
# 17                                                8.7
# 18                                               10.5
# 19                                               12.1
#
#    Estimate!!Percent!!Population 25 years and over!!Bachelor's degree  \
# 0                                                20.7
# 1                                                11.3
# 2                                                10.0
# 3                                                18.2
# 4                                                21.2
# 5                                                13.5
# 6                                                 9.9
# 7                                                21.2
# 8                                                14.1
# 9                                                10.9
# 10                                                4.9
# 11                                                6.9
# 12                                                8.7
# 13                                                6.4
# 14                                               11.6
# 15                                               15.4
# 16                                               14.1
# 17                                                7.4
# 18                                               34.5
# 19                                               29.5
#
#    Estimate!!Percent!!Population 25 years and over!!Graduate or professional degree  \
# 0                                                17.1
# 1                                                 4.9
# 2                                                 8.1
# 3                                                 8.5
# 4                                                19.4
# 5                                                 6.9
# 6                                                 2.0
# 7                                                17.6
# 8                                                10.4
# 9                                                 5.9
# 10                                               10.3
# 11                                                2.8
# 12                                                5.3
# 13                                                1.1
# 14                                                8.0
# 15                                                4.8
# 16                                                6.4
# 17                                                2.6
# 18                                               17.4
# 19                                               20.0
#
#    Estimate!!Percent!!Population 25 years and over!!Percent high school graduate or higher  \
# 0                                                90.6
# 1                                                82.0
# 2                                                86.3
# 3                                                90.0
# 4                                                94.1
# 5                                                81.6
# 6                                                80.6
# 7                                                95.3
# 8                                                89.5
# 9                                                89.8
# 10                                               73.5
# 11                                               77.1
# 12                                               75.0
# 13                                               87.9
# 14                                               89.7
# 15                                               87.6
# 16                                               88.0
# 17                                               71.7
# 18                                               95.3
# 19                                               95.9
#
#    Estimate!!Percent!!Population 25 years and over!!Percent bachelor's degree or higher  \
# 0                                                37.8
# 1                                                16.2
# 2                                                18.1
# 3                                                26.7
# 4                                                40.5
# 5                                                20.4
# 6                                                11.9
# 7                                                38.7
# 8                                                24.5
# 9                                                16.8
# 10                                               15.2
# 11                                                9.7
# 12                                               14.1
# 13                                                7.5
# 14                                               19.6
# 15                                               20.2
# 16                                               20.5
# 17                                               10.1
# 18                                               51.9
# 19                                               49.6
#
#    Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Less than high school graduate  \
# 0                                                 2.5
# 1                                                59.8
# 2                                                17.6
# 3                                                 0.0
# 4                                                61.6
# 5                                                35.1
# 6                                                38.3
# 7                                                31.6
# 8                                                29.0
# 9                                                16.4
# 10                                               20.2
# 11                                               29.5
# 12                                               25.6
# 13                                               31.5
# 14                                               24.8
# 15                                                2.7
# 16                                               31.0
# 17                                               55.1
# 18                                                5.7
# 19                                               15.2
#
#    Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!High school graduate (includes equivalency)  \
# 0                                                11.1
# 1                                                20.5
# 2                                                16.7
# 3                                                 0.8
# 4                                                10.1
# 5                                                 8.1
# 6                                                20.2
# 7                                                 9.1
# 8                                                15.6
# 9                                                 9.2
# 10                                                9.8
# 11                                               22.6
# 12                                               11.1
# 13                                               20.6
# 14                                                4.2
# 15                                               20.2
# 16                                               17.4
# 17                                               29.2
# 18                                                3.4
# 19                                                6.3
#
#    Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Some college or associate's degree  \
# 0                                                15.3
# 1                                                 2.7
# 2                                                 9.8
# 3                                                 2.3
# 4                                                 2.2
# 5                                                 7.9
# 6                                                 7.7
# 7                                                12.4
# 8                                                 4.8
# 9                                                 4.3
# 10                                                6.8
# 11                                                2.2
# 12                                                8.8
# 13                                               11.2
# 14                                                3.4
# 15                                                8.0
# 16                                               12.9
# 17                                                3.1
# 18                                                4.1
# 19                                                4.5
#
#    Estimate!!Percent!!POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Bachelor's degree or higher
# 0                                                 2.3
# 1                                                 6.3
# 2                                                 7.6
# 3                                                 2.5
# 4                                                 4.9
# 5                                                 2.0
# 6                                                 6.5
# 7                                                 1.0
# 8                                                 3.4
# 9                                                 1.4
# 10                                                6.7
# 11                                                5.1
# 12                                                2.3
# 13                                               16.5
# 14                                                1.5
# 15                                                1.0
# 16                                                2.6
# 17                                                0.0
# 18                                                2.7
# 19                                                2.3

# %%
# Look at which strings that are being identified as suspicious to make sure we aren't deleting valuable data
suspicious_strings = set()
for column in suspicious_columns:
    for value in first100rows[column]:
        if not is_numeric(value):
            suspicious_strings.add(value)

suspicious_strings
# Out:
# {'-'}

# %% [markdown]
# It looks like we don't lose any valuable data if we simply convert all these columns to numeric only.

# %%
# Convert all the suspicious columns to numeric
for column in suspicious_columns:
    df[column] = pd.to_numeric(df[column], errors="coerce")

# %% [markdown]
# Next, we clean up the naming by removing the `Estimate!!` and `Total!!` prefixes

# %%
mapper = {}
for column in df.columns:
    mapper[column] = column.replace("Estimate!!", "").replace("Total!!", "").replace("Percent!!", "")
df = df.rename(columns=mapper)

# %%
df.head()
# Out:
#                      id                       Geographic Area Name  \
# 0  1400000US01001020100  Census Tract 201, Autauga County, Alabama
# 1  1400000US01001020200  Census Tract 202, Autauga County, Alabama
# 2  1400000US01001020300  Census Tract 203, Autauga County, Alabama
# 3  1400000US01001020400  Census Tract 204, Autauga County, Alabama
# 4  1400000US01001020500  Census Tract 205, Autauga County, Alabama
#
#    Population 25 years and over!!Less than 9th grade  \
# 0                                                3.0
# 1                                                2.8
# 2                                                4.6
# 3                                                4.0
# 4                                                2.1
#
#    Population 25 years and over!!High school graduate (includes equivalency)  \
# 0                                               29.4
# 1                                               39.9
# 2                                               36.0
# 3                                               36.5
# 4                                               23.4
#
#    Population 25 years and over!!Some college, no degree  \
# 0                                               17.3
# 1                                               18.6
# 2                                               26.0
# 3                                               18.2
# 4                                               21.6
#
#    Population 25 years and over!!Associate's degree  \
# 0                                               6.1
# 1                                               7.2
# 2                                               6.3
# 3                                               8.4
# 4                                               8.6
#
#    Population 25 years and over!!Bachelor's degree  \
# 0                                             20.7
# 1                                             11.3
# 2                                             10.0
# 3                                             18.2
# 4                                             21.2
#
#    Population 25 years and over!!Graduate or professional degree  \
# 0                                               17.1
# 1                                                4.9
# 2                                                8.1
# 3                                                8.5
# 4                                               19.4
#
#    Population 25 years and over!!Percent high school graduate or higher  \
# 0                                               90.6
# 1                                               82.0
# 2                                               86.3
# 3                                               90.0
# 4                                               94.1
#
#    Population 25 years and over!!Percent bachelor's degree or higher  \
# 0                                               37.8
# 1                                               16.2
# 2                                               18.1
# 3                                               26.7
# 4                                               40.5
#
#    POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Less than high school graduate  \
# 0                                                2.5
# 1                                               59.8
# 2                                               17.6
# 3                                                0.0
# 4                                               61.6
#
#    POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!High school graduate (includes equivalency)  \
# 0                                               11.1
# 1                                               20.5
# 2                                               16.7
# 3                                                0.8
# 4                                               10.1
#
#    POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Some college or associate's degree  \
# 0                                               15.3
# 1                                                2.7
# 2                                                9.8
# 3                                                2.3
# 4                                                2.2
#
#    POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Bachelor's degree or higher
# 0                                                2.3
# 1                                                6.3
# 2                                                7.6
# 3                                                2.5
# 4                                                4.9

# %%
for column in df.columns:
    print(column)
# Out:
# id
# Geographic Area Name
# Population 25 years and over!!Less than 9th grade
# Population 25 years and over!!High school graduate (includes equivalency)
# Population 25 years and over!!Some college, no degree
# Population 25 years and over!!Associate's degree
# Population 25 years and over!!Bachelor's degree
# Population 25 years and over!!Graduate or professional degree
# Population 25 years and over!!Percent high school graduate or higher
# Population 25 years and over!!Percent bachelor's degree or higher
# POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Less than high school graduate
# POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!High school graduate (includes equivalency)
# POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Some college or associate's degree
# POVERTY RATE FOR THE POPULATION 25 YEARS AND OVER FOR WHOM POVERTY STATUS IS DETERMINED BY EDUCATIONAL ATTAINMENT LEVEL!!Bachelor's degree or higher

# %% [markdown]
# Now, we can rename the columns to what they actually represent.

# %%
# Clean up some things
mapper = {}
for column in df.columns:
    new_column = column.lower().replace("population 25 years and over!!", "% ")
    new_column = new_column.replace("poverty rate for the population 25 years and over for whom poverty status is determined by educational attainment level!!", "% poverty ")
    new_column = new_column.replace("(includes equivalency)", "")
    mapper[column] = new_column
df = df.rename(columns=mapper)

# %%
df.head()
# Out:
#                      id                       geographic area name  \
# 0  1400000US01001020100  Census Tract 201, Autauga County, Alabama
# 1  1400000US01001020200  Census Tract 202, Autauga County, Alabama
# 2  1400000US01001020300  Census Tract 203, Autauga County, Alabama
# 3  1400000US01001020400  Census Tract 204, Autauga County, Alabama
# 4  1400000US01001020500  Census Tract 205, Autauga County, Alabama
#
#    % less than 9th grade  % high school graduate   % some college, no degree  \
# 0                    3.0                     29.4                       17.3
# 1                    2.8                     39.9                       18.6
# 2                    4.6                     36.0                       26.0
# 3                    4.0                     36.5                       18.2
# 4                    2.1                     23.4                       21.6
#
#    % associate's degree  % bachelor's degree  \
# 0                   6.1                 20.7
# 1                   7.2                 11.3
# 2                   6.3                 10.0
# 3                   8.4                 18.2
# 4                   8.6                 21.2
#
#    % graduate or professional degree  \
# 0                               17.1
# 1                                4.9
# 2                                8.1
# 3                                8.5
# 4                               19.4
#
#    % percent high school graduate or higher  \
# 0                                      90.6
# 1                                      82.0
# 2                                      86.3
# 3                                      90.0
# 4                                      94.1
#
#    % percent bachelor's degree or higher  \
# 0                                   37.8
# 1                                   16.2
# 2                                   18.1
# 3                                   26.7
# 4                                   40.5
#
#    % poverty less than high school graduate  % poverty high school graduate   \
# 0                                       2.5                             11.1
# 1                                      59.8                             20.5
# 2                                      17.6                             16.7
# 3                                       0.0                              0.8
# 4                                      61.6                             10.1
#
#    % poverty some college or associate's degree  \
# 0                                          15.3
# 1                                           2.7
# 2                                           9.8
# 3                                           2.3
# 4                                           2.2
#
#    % poverty bachelor's degree or higher
# 0                                    2.3
# 1                                    6.3
# 2                                    7.6
# 3                                    2.5
# 4                                    4.9

# %% [markdown]
# Now, all the column names can be formatted as camel case to match the rest of the data.

# %%
def spaces_to_camel(spaces):
    l = spaces.split(" ")
    out = l[0].lower()
    for word in l[1:]:
        out += word.capitalize().replace("'", "")
    return out

# Camel case everything
mapper = {}
for column in df.columns:
    mapper[column] = spaces_to_camel(column)
df = df.rename(columns=mapper)

# %%
df.head()
# Out:
#                      id                         geographicAreaName  \
# 0  1400000US01001020100  Census Tract 201, Autauga County, Alabama
# 1  1400000US01001020200  Census Tract 202, Autauga County, Alabama
# 2  1400000US01001020300  Census Tract 203, Autauga County, Alabama
# 3  1400000US01001020400  Census Tract 204, Autauga County, Alabama
# 4  1400000US01001020500  Census Tract 205, Autauga County, Alabama
#
#    %LessThan9thGrade  %HighSchoolGraduate  %SomeCollege,NoDegree  \
# 0                3.0                 29.4                   17.3
# 1                2.8                 39.9                   18.6
# 2                4.6                 36.0                   26.0
# 3                4.0                 36.5                   18.2
# 4                2.1                 23.4                   21.6
#
#    %AssociatesDegree  %BachelorsDegree  %GraduateOrProfessionalDegree  \
# 0                6.1              20.7                           17.1
# 1                7.2              11.3                            4.9
# 2                6.3              10.0                            8.1
# 3                8.4              18.2                            8.5
# 4                8.6              21.2                           19.4
#
#    %PercentHighSchoolGraduateOrHigher  %PercentBachelorsDegreeOrHigher  \
# 0                                90.6                             37.8
# 1                                82.0                             16.2
# 2                                86.3                             18.1
# 3                                90.0                             26.7
# 4                                94.1                             40.5
#
#    %PovertyLessThanHighSchoolGraduate  %PovertyHighSchoolGraduate  \
# 0                                 2.5                        11.1
# 1                                59.8                        20.5
# 2                                17.6                        16.7
# 3                                 0.0                         0.8
# 4                                61.6                        10.1
#
#    %PovertySomeCollegeOrAssociatesDegree  %PovertyBachelorsDegreeOrHigher
# 0                                   15.3                              2.3
# 1                                    2.7                              6.3
# 2                                    9.8                              7.6
# 3                                    2.3                              2.5
# 4                                    2.2                              4.9

# %% [markdown]
# Finally, do some fine tuning to match special column names

# %%
# Format tract ID to be the same
df = df.rename(columns={"id": "tractID"})
df["tractID"] = df["tractID"].apply(lambda x: int(x.split("US")[1]))

# %%
# Format special cases
df = df.rename(columns={"geographicAreaName": "areaName", "populationSomeCollege,NoDegree": "populationSomeCollege"})

# %%
# Drop area name because we already have it in other data
df = df.drop(columns=["areaName"])

# %%
df.head()
# Out:
#       tractID  %LessThan9thGrade  %HighSchoolGraduate  %SomeCollege,NoDegree  \
# 0  1001020100                3.0                 29.4                   17.3
# 1  1001020200                2.8                 39.9                   18.6
# 2  1001020300                4.6                 36.0                   26.0
# 3  1001020400                4.0                 36.5                   18.2
# 4  1001020500                2.1                 23.4                   21.6
#
#    %AssociatesDegree  %BachelorsDegree  %GraduateOrProfessionalDegree  \
# 0                6.1              20.7                           17.1
# 1                7.2              11.3                            4.9
# 2                6.3              10.0                            8.1
# 3                8.4              18.2                            8.5
# 4                8.6              21.2                           19.4
#
#    %PercentHighSchoolGraduateOrHigher  %PercentBachelorsDegreeOrHigher  \
# 0                                90.6                             37.8
# 1                                82.0                             16.2
# 2                                86.3                             18.1
# 3                                90.0                             26.7
# 4                                94.1                             40.5
#
#    %PovertyLessThanHighSchoolGraduate  %PovertyHighSchoolGraduate  \
# 0                                 2.5                        11.1
# 1                                59.8                        20.5
# 2                                17.6                        16.7
# 3                                 0.0                         0.8
# 4                                61.6                        10.1
#
#    %PovertySomeCollegeOrAssociatesDegree  %PovertyBachelorsDegreeOrHigher
# 0                                   15.3                              2.3
# 1                                    2.7                              6.3
# 2                                    9.8                              7.6
# 3                                    2.3                              2.5
# 4                                    2.2                              4.9

# %% [markdown]
# Now, the data looks very nice and clean so we can save it.

# %%
# Save data
df = df.dropna()
df.to_csv("../Clean Data/educationData.csv", index=False)
